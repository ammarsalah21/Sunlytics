# %%
import pandas as pd

# %%
# Step 1: Load all sheets
excel_path = "SolarData.xlsx"
sheets = pd.read_excel(excel_path, sheet_name=None)

# %%
# Step 2: Convert the dictionary into a list of DataFrames
dfs = list(sheets.values())

# %%
# Sort each DataFrame by 'Year' and show the first 5 rows
for i, df in enumerate(dfs, start=1):
    df.sort_values(by="Year", inplace=True)
    print(f"----- Sheet {i} (first 5 rows) -----")
    print(df.head())
    print()
# Out:
# ----- Sheet 1 (first 5 rows) -----
#       Country  Year  Solar (TWh growth - equivalent)
# 0      Africa  2000                         0.033586
# 50    Algeria  2000                         0.000000
# 1125    Italy  2000                         0.002778
# 1350   Mexico  2000                         0.000000
# 550   Czechia  2000                         0.000000
#
# ----- Sheet 2 (first 5 rows) -----
#       Country  Year  Annual CO₂ emissions (per capita)
# 5492   Zambia  2000                           0.178097
# 2780  Lesotho  2000                           0.923351
# 3020   Malawi  2000                           0.075791
# 2184    Haiti  2000                           0.196810
# 72    Algeria  2000                           2.763361
#
# ----- Sheet 3 (first 5 rows) -----
#           Country  Year  GDP per capita
# 0     Afghanistan  2000       502.37274
# 46        Algeria  2000      6834.55370
# 23        Albania  2000      4808.47950
# 3954     Zimbabwe  2000      2211.19630
# 92      Argentina  2000     14368.94200
#
# ----- Sheet 4 (first 5 rows) -----
#       Country  Year  Solar capacity (total) (GW)
# 16     Africa  2000                     0.008355
# 755     China  2000                     0.033515
# 3805    Tonga  2000                     0.000057
# 992   Denmark  2000                     0.001000
# 953   Czechia  2000                     0.000100
#
# ----- Sheet 5 (first 5 rows) -----
#           Country  Year  Solar per capita (kWh - equivalent)
# 0          Africa  2000                             0.040437
# 650        France  2000                             0.243916
# 1475  Philippines  2000                             0.000000
# 50      Argentina  2000                             0.002687
# 2025      Ukraine  2000                             0.000000
#
# ----- Sheet 6 (first 5 rows) -----
#                              Country  Year  Electricity from solar - TWh
# 80                    Africa (Ember)  2000                      0.010000
# 2070                         Oceania  2000                      0.050000
# 2094                 Oceania (Ember)  2000                      0.050000
# 2651  South and Central America (EI)  2000                      0.002542
# 568                            China  2000                      0.020000
#
# ----- Sheet 7 (first 5 rows) -----
#    Country  Year  Solar photovoltaic module price  \
# 0    World  2000                         6.294375
# 25   World  2000                         6.294375
# 26   World  2001                         6.089497
# 1    World  2001                         6.089497
# 2    World  2002                         5.568966
#
#     Solar photovoltaic cumulative capacity
# 0                                   1103.0
# 25                                  1103.0
# 26                                  1373.0
# 1                                   1373.0
# 2                                   1738.5
#
# ----- Sheet 8 (first 5 rows) -----
#                   Country  Year World Bank's income classification  \
# 0             Afghanistan  2000               Low-income countries
# 5373             Zimbabwe  2000               Low-income countries
# 650                Brazil  2000      Upper-middle-income countries
# 1960            Greenland  2000              High-income countries
# 4921  Trinidad and Tobago  2000      Upper-middle-income countries
#
#       World Bank's income classification.1
# 0                                        0
# 5373                                     0
# 650                                      2
# 1960                                     3
# 4921                                     2
#
# ----- Sheet 9 (first 5 rows) -----
#                                   Country  Year  Electricity from solar (TWh)
# 2352                                World  2000                          1.08
# 1146  Latin America and Caribbean (Ember)  2000                          0.02
# 1651                         OECD (Ember)  2000                          1.04
# 942                 High-income countries  2000                          1.02
# 661                                Europe  2000                          0.12
#
# ----- Sheet 10 (first 5 rows) -----
#              Country  Year  Solar (% equivalent primary energy)
# 0             Africa  2000                             0.001101
# 78              Asia  2000                             0.003063
# 1122       OECD (BP)  2000                             0.004655
# 448            Egypt  2000                             0.000104
# 1623  United Kingdom  2000                             0.000111
#
# ----- Sheet 11 (first 5 rows) -----
#             Country  Year  Urban population
# 0       Afghanistan  1960           8276009
# 9295          Nauru  1960                 0
# 65          Albania  1960           1114818
# 5005        Germany  1960          20836712
# 12255  South Africa  1960           8775928
#
# ----- Sheet 12 (first 5 rows) -----
#              Country  Year  Rural population
# 5675        Zimbabwe  2000           7877535
# 75    American Samoa  2000              6489
# 5225    Turkmenistan  2000           2478633
# 0        Afghanistan  2000          15685953
# 25           Albania  2000           1799636
#
# ----- Sheet 13 (first 5 rows) -----
#       Year              Country  population
# 1776  2000                 Togo      840913
# 5712  2000                  NaN    49556654
# 1824  2000         Turkmenistan    59483716
# 72    2000  Antigua and Barbuda    30903894
# 4416  2000                  NaN    38258077

# %%
# Step 3: Merge all sheets on Country and Year (outer join)
# Start with the first sheet
merged_df = dfs[0]

for df in dfs[1:]:
    merged_df = pd.merge(merged_df, df, on=["Country", "Year"], how="outer")

# %%
# Step 4: Save to Excel or CSV
merged_df.to_excel("Merged_SolarData.xlsx", index=False)
# or
# merged_df.to_csv("Merged_SolarData.csv", index=False)

# %%
merged_df = pd.read_excel("Merged_SolarData.xlsx")

# %%
print(type(merged_df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
cleaned_df = merged_df[merged_df["Year"] >= 2000]

# %%
cleaned_df.reset_index(drop=True, inplace=True)

# %%
cleaned_df.to_excel("Cleaned_SolarData.xlsx", index=False)

# %%
# Shape of the dataset (rows, columns)
print(cleaned_df.shape)
# Out:
# (11981, 17)

# %%
# Column names
print(cleaned_df.columns.tolist())
# Out:
# ['Country', 'Year', 'Solar (TWh growth - equivalent)', 'Annual CO₂ emissions (per capita)', 'GDP per capita', 'Solar capacity (total) (GW)', 'Solar per capita (kWh - equivalent)', 'Electricity from solar - TWh', 'Solar photovoltaic module price', 'Solar photovoltaic cumulative capacity', "World Bank's income classification", "World Bank's income classification.1", 'Electricity from solar (TWh)', 'Solar (% equivalent primary energy)', 'Urban population', 'Rural population', 'population']

# %%
# Drop the unwanted column
cleaned_df.drop(columns=["Solar photovoltaic cumulative capacity"], inplace=True)
# Out:
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1934960021.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cleaned_df.drop(columns=["Solar photovoltaic cumulative capacity"], inplace=True)

# %%
cleaned_df.drop(columns=["Solar photovoltaic module price"], inplace=True)

# %%
# Drop rows where Country == 'World'
cleaned_df = cleaned_df[cleaned_df["Country"] != "World"]

# Reset the index for a clean DataFrame
cleaned_df.reset_index(drop=True, inplace=True)

# %%
# Quick summary of all columns
print(cleaned_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7781 entries, 0 to 7780
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Country                               7781 non-null   object
#  1   Year                                  7781 non-null   int64
#  2   Solar (TWh growth - equivalent)       2750 non-null   float64
#  3   Annual CO₂ emissions (per capita)     5516 non-null   float64
#  4   GDP per capita                        3967 non-null   float64
#  5   Solar capacity (total) (GW)           4215 non-null   float64
#  6   Solar per capita (kWh - equivalent)   2225 non-null   float64
#  7   Electricity from solar - TWh          3101 non-null   float64
#  8   World Bank's income classification    5398 non-null   object
#  9   World Bank's income classification.1  5398 non-null   float64
#  10  Electricity from solar (TWh)          2370 non-null   float64
#  11  Solar (% equivalent primary energy)   1741 non-null   float64
#  12  Urban population                      5675 non-null   float64
#  13  Rural population                      5675 non-null   float64
#  14  population                            1990 non-null   float64
# dtypes: float64(12), int64(1), object(2)
# memory usage: 912.0+ KB
# None

# %%
cleaned_df = cleaned_df.dropna(subset=["Country"])

# %%
# Reset the index
cleaned_df.reset_index(drop=True, inplace=True)

# %%
# Quick summary of all columns
print(cleaned_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7781 entries, 0 to 7780
# Data columns (total 15 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Country                               7781 non-null   object
#  1   Year                                  7781 non-null   int64
#  2   Solar (TWh growth - equivalent)       2750 non-null   float64
#  3   Annual CO₂ emissions (per capita)     5516 non-null   float64
#  4   GDP per capita                        3967 non-null   float64
#  5   Solar capacity (total) (GW)           4215 non-null   float64
#  6   Solar per capita (kWh - equivalent)   2225 non-null   float64
#  7   Electricity from solar - TWh          3101 non-null   float64
#  8   World Bank's income classification    5398 non-null   object
#  9   World Bank's income classification.1  5398 non-null   float64
#  10  Electricity from solar (TWh)          2370 non-null   float64
#  11  Solar (% equivalent primary energy)   1741 non-null   float64
#  12  Urban population                      5675 non-null   float64
#  13  Rural population                      5675 non-null   float64
#  14  population                            1990 non-null   float64
# dtypes: float64(12), int64(1), object(2)
# memory usage: 912.0+ KB
# None

# %%
cleaned_df.drop(columns=["population"], inplace=True)

# %%
# Quick summary of all columns
print(cleaned_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7781 entries, 0 to 7780
# Data columns (total 14 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   Country                               7781 non-null   object
#  1   Year                                  7781 non-null   int64
#  2   Solar (TWh growth - equivalent)       2750 non-null   float64
#  3   Annual CO₂ emissions (per capita)     5516 non-null   float64
#  4   GDP per capita                        3967 non-null   float64
#  5   Solar capacity (total) (GW)           4215 non-null   float64
#  6   Solar per capita (kWh - equivalent)   2225 non-null   float64
#  7   Electricity from solar - TWh          3101 non-null   float64
#  8   World Bank's income classification    5398 non-null   object
#  9   World Bank's income classification.1  5398 non-null   float64
#  10  Electricity from solar (TWh)          2370 non-null   float64
#  11  Solar (% equivalent primary energy)   1741 non-null   float64
#  12  Urban population                      5675 non-null   float64
#  13  Rural population                      5675 non-null   float64
# dtypes: float64(11), int64(1), object(2)
# memory usage: 851.2+ KB
# None

# %%
import pandas as pd

# Assuming your merged and cleaned data is in "cleaned_df"
# (if it's called merged_df instead, just replace it below)

# 1️⃣ Main area — Growth & Urbanization
main_df = cleaned_df[[
    "Country",
    "Year",
    "Solar capacity (total) (GW)",
    "World Bank's income classification",
    "Urban population"
]].copy()

# 2️⃣ Efficiency area — Economic & Operational Efficiency
efficiency_df = cleaned_df[[
    "Country",
    "Year",
    
    "Solar capacity (total) (GW)",
    "Solar per capita (kWh - equivalent)",
    "GDP per capita",
    "Electricity from solar - TWh"
]].copy()

# 3️⃣ Environment area — Environmental Impact & Policies
environment_df = cleaned_df[[
    "Country",
    "Year",
    "Solar (TWh growth - equivalent)",
    "Annual CO₂ emissions (per capita)",
    "Electricity from solar (TWh)",
    "Solar (% equivalent primary energy)"
]].copy()

# 4️⃣ Save all three to Excel files
main_df.to_excel("Main_Data.xlsx", index=False)
efficiency_df.to_excel("Efficiency_Data.xlsx", index=False)
environment_df.to_excel("Environment_Data.xlsx", index=False)

print("✅ All DataFrames created and saved successfully!")
# Out:
# ✅ All DataFrames created and saved successfully!

# %%
# 1️⃣ Define a function to clean the DataFrames
def clean_table(df):
    exclude_cols = ["Country", "Year"]
    other_cols = [col for col in df.columns if col not in exclude_cols]
    return df.dropna(subset=other_cols, how="all").reset_index(drop=True)

# 2️⃣ Apply cleaning to all three tables
main_df = clean_table(main_df)
efficiency_df = clean_table(efficiency_df)
environment_df = clean_table(environment_df)

# 3️⃣ Save them all into a NEW Excel file
with pd.ExcelWriter("Cleaned_Solar_Study_Areas.xlsx") as writer:
    main_df.to_excel(writer, sheet_name="Main_Area", index=False)
    efficiency_df.to_excel(writer, sheet_name="Efficiency_Area", index=False)
    environment_df.to_excel(writer, sheet_name="Environment_Area", index=False)

print("✅ Cleaned data saved successfully in 'Cleaned_Solar_Study_Areas.xlsx'")
# Out:
# ✅ Cleaned data saved successfully in 'Cleaned_Solar_Study_Areas.xlsx'

# %%
# Display basic info (data types, non-null counts, etc.)
print("📘 MAIN DATAFRAME INFO")
print(main_df.info())
print("\n")

print("⚙️ EFFICIENCY DATAFRAME INFO")
print(efficiency_df.info())
print("\n")

print("🌿 ENVIRONMENT DATAFRAME INFO")
print(environment_df.info())
print("\n")

# Display basic statistics for numerical columns
print("📊 MAIN DATAFRAME DESCRIPTION")
print(main_df.describe())
print("\n")

print("⚙️ EFFICIENCY DATAFRAME DESCRIPTION")
print(efficiency_df.describe())
print("\n")

print("🌿 ENVIRONMENT DATAFRAME DESCRIPTION")
print(environment_df.describe())
print("\n")

# Check for missing values in each table
print("🚨 Missing Values Summary:")
print("Main DF:\n", main_df.isnull().sum())
print("\nEfficiency DF:\n", efficiency_df.isnull().sum())
print("\nEnvironment DF:\n", environment_df.isnull().sum())
# Out:
# 📘 MAIN DATAFRAME INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6135 entries, 0 to 6134
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Country                             6135 non-null   object
#  1   Year                                6135 non-null   int64
#  2   Solar capacity (total) (GW)         4215 non-null   float64
#  3   World Bank's income classification  5398 non-null   object
#  4   Urban population                    5675 non-null   float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 239.8+ KB
# None
#
#
# ⚙️ EFFICIENCY DATAFRAME INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6299 entries, 0 to 6298
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Country                              6299 non-null   object
#  1   Year                                 6299 non-null   int64
#  2   Solar capacity (total) (GW)          4215 non-null   float64
#  3   Solar per capita (kWh - equivalent)  2225 non-null   float64
#  4   GDP per capita                       3967 non-null   float64
#  5   Electricity from solar - TWh         3101 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 295.4+ KB
# None
#
#
# 🌿 ENVIRONMENT DATAFRAME INFO
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6649 entries, 0 to 6648
# Data columns (total 6 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Country                              6649 non-null   object
#  1   Year                                 6649 non-null   int64
#  2   Solar (TWh growth - equivalent)      2750 non-null   float64
#  3   Annual CO₂ emissions (per capita)    5516 non-null   float64
#  4   Electricity from solar (TWh)         2370 non-null   float64
#  5   Solar (% equivalent primary energy)  1741 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 311.8+ KB
# None
#
#
# 📊 MAIN DATAFRAME DESCRIPTION
#               Year  Solar capacity (total) (GW)  Urban population
# count  6135.000000                  4215.000000      5.675000e+03
# mean   2012.108720                     6.504349      4.508084e+07
# std       7.208078                    47.862359      1.830819e+08
# min    2000.000000                     0.000001      0.000000e+00
# 25%    2006.000000                     0.001000      2.219255e+05
# 50%    2012.000000                     0.010000      2.291593e+06
# 75%    2018.000000                     0.189138      1.140190e+07
# max    2024.000000                  1200.919000      1.825486e+09
#
#
# ⚙️ EFFICIENCY DATAFRAME DESCRIPTION
#               Year  Solar capacity (total) (GW)  \
# count  6299.000000                  4215.000000
# mean   2012.572631                     6.504349
# std       7.121006                    47.862359
# min    2000.000000                     0.000001
# 25%    2007.000000                     0.001000
# 50%    2013.000000                     0.010000
# 75%    2019.000000                     0.189138
# max    2024.000000                  1200.919000
#
#        Solar per capita (kWh - equivalent)  GDP per capita  \
# count                          2225.000000     3967.000000
# mean                            188.666122    16698.831629
# std                             437.819332    18129.711208
# min                               0.000000      403.601900
# 25%                               0.033004     3584.676050
# 50%                               5.171760    10573.861000
# 75%                             140.074700    24230.719000
# max                            4584.595700   160051.230000
#
#        Electricity from solar - TWh
# count                   3101.000000
# mean                      24.828321
# std                      107.552485
# min                        0.000007
# 25%                        0.020000
# 50%                        0.190000
# 75%                        2.600000
# max                     1946.000000
#
#
# 🌿 ENVIRONMENT DATAFRAME DESCRIPTION
#               Year  Solar (TWh growth - equivalent)  \
# count  6649.000000                      2750.000000
# mean   2011.696646                         9.604454
# std       6.996315                        47.792990
# min    2000.000000                        -4.591518
# 25%    2006.000000                         0.000000
# 50%    2012.000000                         0.021812
# 75%    2018.000000                         0.926111
# max    2024.000000                       790.888900
#
#        Annual CO₂ emissions (per capita)  Electricity from solar (TWh)  \
# count                        5516.000000                   2370.000000
# mean                            5.112057                     17.309706
# std                             6.353274                     66.335454
# min                             0.021731                      0.000007
# 25%                             0.876049                      0.020000
# 50%                             3.143872                      0.150000
# 75%                             7.208018                      2.177500
# max                            67.583740                    937.750000
#
#        Solar (% equivalent primary energy)
# count                         1.741000e+03
# mean                          4.005507e-01
# std                           7.702648e-01
# min                           2.177368e-07
# 25%                           3.301054e-03
# 50%                           3.037901e-02
# 75%                           4.269756e-01
# max                           5.999280e+00
#
#
# 🚨 Missing Values Summary:
# Main DF:
#  Country                                  0
# Year                                     0
# Solar capacity (total) (GW)           1920
# World Bank's income classification     737
# Urban population                       460
# dtype: int64
#
# Efficiency DF:
#  Country                                   0
# Year                                      0
# Solar capacity (total) (GW)            2084
# Solar per capita (kWh - equivalent)    4074
# GDP per capita                         2332
# Electricity from solar - TWh           3198
# dtype: int64
#
# Environment DF:
#  Country                                   0
# Year                                      0
# Solar (TWh growth - equivalent)        3899
# Annual CO₂ emissions (per capita)      1133
# Electricity from solar (TWh)           4279
# Solar (% equivalent primary energy)    4908
# dtype: int64

# %%
main_df.isnull().sum()
efficiency_df.isnull().sum()
environment_df.isnull().sum()
# Out:
# Country                                   0
# Year                                      0
# Solar (TWh growth - equivalent)        3899
# Annual CO₂ emissions (per capita)      1133
# Electricity from solar (TWh)           4279
# Solar (% equivalent primary energy)    4908
# dtype: int64

# %%
# Fill missing numeric values by country (forward then backward)
for df in [main_df, efficiency_df, environment_df]:
    df.sort_values(["Country", "Year"], inplace=True)
    df = df.groupby("Country").apply(lambda group: group.ffill().bfill()).reset_index(drop=True)
# Out:
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1066833233.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df = df.groupby("Country").apply(lambda group: group.ffill().bfill()).reset_index(drop=True)
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1066833233.py:4: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("Country").apply(lambda group: group.ffill().bfill()).reset_index(drop=True)
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1066833233.py:4: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("Country").apply(lambda group: group.ffill().bfill()).reset_index(drop=True)
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1066833233.py:4: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   df = df.groupby("Country").apply(lambda group: group.ffill().bfill()).reset_index(drop=True)

# %%
main_df["World Bank's income classification"] = main_df["World Bank's income classification"].fillna("Unknown")

# %%
for df in [main_df, efficiency_df, environment_df]:
    df.fillna(0, inplace=True)

# %%
with pd.ExcelWriter("Cleaned_Solar_Study_Areas_Filled.xlsx") as writer:
    main_df.to_excel(writer, sheet_name="Main", index=False)
    efficiency_df.to_excel(writer, sheet_name="Efficiency", index=False)
    environment_df.to_excel(writer, sheet_name="Environment", index=False)

print("✅ All nulls filled and saved in 'Cleaned_Solar_Study_Areas_Filled.xlsx'")
# Out:
# ✅ All nulls filled and saved in 'Cleaned_Solar_Study_Areas_Filled.xlsx'

# %%
# Interpolate missing numeric values per country, keeping text columns intact
for df in [main_df, efficiency_df, environment_df]:
    # Sort to ensure interpolation follows time order
    df.sort_values(["Country", "Year"], inplace=True)
    
    # Apply interpolation for each country separately
    df.update(
        df.groupby("Country")
          .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
          .reset_index(drop=True)
    )
# Out:
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
# ...
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2822510749.py:9: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.interpolate(method='linear', limit_direction='both'))

# %%
with pd.ExcelWriter("Cleaned_Solar_Study_Areas_Interpolated.xlsx") as writer:
    main_df.to_excel(writer, sheet_name="Main", index=False)
    efficiency_df.to_excel(writer, sheet_name="Efficiency", index=False)
    environment_df.to_excel(writer, sheet_name="Environment", index=False)

print("✅ Interpolation completed and saved to 'Cleaned_Solar_Study_Areas_Interpolated.xlsx'")
# Out:
# ✅ Interpolation completed and saved to 'Cleaned_Solar_Study_Areas_Interpolated.xlsx'

# %%
with pd.ExcelWriter("Cleaned_Solar_Study_Areas_Interpolated.xlsx") as writer:
    main_df.to_excel(writer, sheet_name="Main", index=False)
    efficiency_df.to_excel(writer, sheet_name="Efficiency", index=False)
    environment_df.to_excel(writer, sheet_name="Environment", index=False)

print("✅ Interpolation completed and saved to 'Cleaned_Solar_Study_Areas_Interpolated.xlsx'")
# Out:
# ✅ Interpolation completed and saved to 'Cleaned_Solar_Study_Areas_Interpolated.xlsx'

# %%
import pandas as pd
import numpy as np

# Step 1️⃣ Replace all zeros with NaN (only for numeric columns)
for df in [main_df, efficiency_df, environment_df]:
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    df[numeric_cols] = df[numeric_cols].replace(0, np.nan)

# Step 2️⃣ Interpolate missing values by Country and Year
for df in [main_df, efficiency_df, environment_df]:
    df.sort_values(["Country", "Year"], inplace=True)
    df.update(
        df.groupby("Country")
          .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
          .reset_index(drop=True)
    )

# Step 3️⃣ Save final cleaned and interpolated data into one Excel file
final_filename = "Final_Solar_Study_Areas.xlsx"

with pd.ExcelWriter(final_filename, engine="openpyxl") as writer:
    main_df.to_excel(writer, sheet_name="Main", index=False)
    efficiency_df.to_excel(writer, sheet_name="Efficiency", index=False)
    environment_df.to_excel(writer, sheet_name="Environment", index=False)

print("✅ Final interpolated data saved successfully to:", final_filename)
# Out:
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# ...
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\1377214685.py:14: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# ✅ Final interpolated data saved successfully to: Final_Solar_Study_Areas.xlsx

# %%
import pandas as pd
import numpy as np

# 1️⃣ Replace 0 with NaN for numeric columns (to avoid false zeros)
for df in [main_df, efficiency_df, environment_df]:
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    df[numeric_cols] = df[numeric_cols].replace(0, np.nan)

# 2️⃣ Interpolate missing values per country and year
for df in [main_df, efficiency_df, environment_df]:
    df.sort_values(["Country", "Year"], inplace=True)
    df.update(
        df.groupby("Country")
          .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
          .reset_index(drop=True)
    )

# 3️⃣ Drop any rows that still contain null values (NaN)
main_cleaned = main_df.dropna()
efficiency_cleaned = efficiency_df.dropna()
environment_cleaned = environment_df.dropna()

# 4️⃣ Save all the cleaned DataFrames into a new Excel file
final_clean_filename = "Final_Cleaned_Solar_Study_Areas.xlsx"

with pd.ExcelWriter(final_clean_filename, engine="openpyxl") as writer:
    main_cleaned.to_excel(writer, sheet_name="Main_Cleaned", index=False)
    efficiency_cleaned.to_excel(writer, sheet_name="Efficiency_Cleaned", index=False)
    environment_cleaned.to_excel(writer, sheet_name="Environment_Cleaned", index=False)

print("✅ Fully cleaned (no nulls) data saved successfully to:", final_clean_filename)
# Out:
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# ...
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\2535710904.py:14: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# ✅ Fully cleaned (no nulls) data saved successfully to: Final_Cleaned_Solar_Study_Areas.xlsx

# %%
import pandas as pd
import numpy as np

# 1️⃣ Replace 0 with NaN for numeric columns (to avoid false zeros)
for df in [main_df, efficiency_df, environment_df]:
    numeric_cols = df.select_dtypes(include=[np.number]).columns
    df[numeric_cols] = df[numeric_cols].replace(0, np.nan)

# 2️⃣ Interpolate missing numeric values by country and year
for df in [main_df, efficiency_df, environment_df]:
    df.sort_values(["Country", "Year"], inplace=True)
    df.update(
        df.groupby("Country")
          .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
          .reset_index(drop=True)
    )

# 3️⃣ Drop rows where "World Bank's income classification" == "Unknown" in main_df
main_df = main_df[main_df["World Bank's income classification"] != "Unknown"]

# 4️⃣ Drop any rows that still contain null values (NaN)
main_cleaned = main_df.dropna()
efficiency_cleaned = efficiency_df.dropna()
environment_cleaned = environment_df.dropna()

# 5️⃣ Save all cleaned DataFrames into a new Excel file
final_clean_filename = "Final_Cleaned_Solar_Study_Areas.xlsx"

with pd.ExcelWriter(final_clean_filename, engine="openpyxl") as writer:
    main_cleaned.to_excel(writer, sheet_name="Main_Cleaned", index=False)
    efficiency_cleaned.to_excel(writer, sheet_name="Efficiency_Cleaned", index=False)
    environment_cleaned.to_excel(writer, sheet_name="Environment_Cleaned", index=False)

print("✅ Fully cleaned data saved successfully to:", final_clean_filename)
print("🗑️ Dropped rows in main_df where income classification was 'Unknown'.")
# Out:
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# ...
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrame.interpolate with object dtype is deprecated and will raise in a future version. Call obj.infer_objects(copy=False) before interpolating instead.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# C:\Users\alhaiaah\AppData\Local\Temp\ipykernel_7600\3945053482.py:14: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: g.interpolate(method="linear", limit_direction="both"))
# ✅ Fully cleaned data saved successfully to: Final_Cleaned_Solar_Study_Areas.xlsx
# 🗑️ Dropped rows in main_df where income classification was 'Unknown'.
